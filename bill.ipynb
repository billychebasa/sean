# %% [markdown]
# <a href="https://colab.research.google.com/github/billychebasa/sean/blob/main/bill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # this is the title

# %%
print("hello world")
# Out:
# hello world

# %%
3-2
# Out:
# 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# this *is the![MARKETER.png](data:image/png;base64,...)* **heading**

# %% [markdown]
# [google search](https://google.com)
